# %% [markdown]
# # Colaboratory Assignment 3.3
#
# **Instructions**. Below you will find several text cells with programming (short) problems. You will create how many code cells you need to answer them.
#
# There are four problem, but you will only need to solve two. You **must** choose at least one of the problems with the title in <font color='#006633'>green</font>.
#
#
# **BEFORE YOU START**
#
# Complete the cell below with your name. Also remember, if you get an error when trying to use `networkx`'s function `adjacency_matrix()`, remember to uninstall `scipy` and `networkx` and then install the correct versions (`1.8` and `2.7`, respectively), as shown in the video in Blackboard (Lesson 3 content section).

# %% [markdown]
# ## <font color='#006633'>1. Airports network </font>
#
# This problem is intended for you to practice the use of the adjacency matrix to extract information from a network.
#
# Import the airports (`airline-net-und-2017.dat`) network and obtain the following quantities **using the adjacency matrix**. Check your results without using the adjacency matrix (i.e. with the bulit-in functions from `networkx`).
#
# 1. $n$
# 2. $m$
# 4. $\rho$

# %%
from readlist import readlist
import networkx as nx

airports = readlist('Notebooks/airline-net-und-2017.dat',0)

A = nx.adjacency_matrix(airports)
A = A.toarray()

n = len(A)
m = sum(sum(A))/2
rho = n*(n-1)/2

n1 = airports.order()
m1 = airports.size()
rho1 = nx.density(airports)

print(n, m, rho)
print(n1, m1, rho1)

# %% [markdown]
# ## 2. Airport in Santiago, Chile
#
# Use the network created in the previous problem to create an adjacency matrix and from it, calculate the degree of the Santiago International Airport (`SCL`)

# %%
labels = list(airports.nodes())

for list_ in airports_mat:
  temp_list = list()
  temp_n = 0
  for i in list_:
    if i == 1:
      if labels[n] != labels[temp_n]:
        temp_list.append(labels[temp_n])
    temp_n += 1
  nodes_id[labels[n]] = temp_list
  n += 1

  print(len(nodes_id['SCL']))

# %% [markdown]
# ## 3. Densities through adjacency matrix
#
# In the first problem of this assignment you found the density for the airports network. Repeat the procedure, and find the density for the Coauthorship network (`ca-CondMat-noself.txt`, skip the first 4 lines) using its adjacency matrix.
#
# The number of nodes in these networks are not *comparable*. Do their densities show similarities? To answer this question, compare the densities for the airports and the coauthorship network and interpret the numbers.
#
# Note that the coauthorship network contains more nodes than the airports network. Thus, it will take more time to calculate the density from the adjacency matrix (expect around 5 minutes)

# %%
#coauthorship = readlist('ca-CondMat-noself.txt',4)

# %% [markdown]
# ## <font color='#006633'>4. Constant $\langle k \rangle$ </font>
#
# Network $G$ has $n$ nodes and its average degree is a constant value, regardless of $n$. There are several networks that satisfy these conditions. Write `Python` code to create one of these networks and show that $\langle k \rangle$ is constant and independent of $n$.
