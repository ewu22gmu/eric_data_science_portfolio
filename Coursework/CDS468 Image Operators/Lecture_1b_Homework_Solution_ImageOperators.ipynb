# %% [markdown]
# <br><br><br><br>
#
# ### Creation Operator List
#
# <br><br>
#
# <div class="alert alert-block alert-info">
# ${\bf z}_{\vec w}$ Zeros - returns an image of size $\vec w$ with all pixels set to 0<br><br>
# ${\bf r}_{\vec w; \vec v_1, \vec v_2} [\vec x]$ Rectangle- returns an image with a solid rectangle located at $\vec v_1$ and size $\vec v_2$<br><br>
# ${\bf o}_{\vec w; \vec v, r}[\vec x]$ Circle - returns an image with a solid circle of radius $r$ located at position $\vec v$<br><br>
# ${\bf q}_{\vec w} [\vec x]$ Random - returns an image with random numbers between 0 and 1<br><br>
# $\mathfrak{G}_{\vec w,\vec f, \vec t, sw} [\vec x]$ Gabor - returns a set of images that are Gabor filters<br><br>
# $Y({\tt fileName} )$ Load - loads a file<br><br>
# $\mathcal{Z}_{\vec w;r,m,n} [\vec x]$ Zernike - returns a set of images that are Zernike functions<br><br>
# $k_{\vec w; r_1, r_2} [\vec x]$ Kaiser - returns an image which contains a Kaiser mask with an inner radius of $r_1$ and an outer radius of $r_2$<br><br>
# </div>
#
# <br><br><br><br>

# %% [markdown]
# ##  Lecture 1b Operators
#
# <br><br>
#
# 1. Given $\vec w = (200,200)$, $\vec v_1 = (10,100)$ and $\vec v_2 = (50, 150)$, how many pixels are set to 1 in ${\bf a}[\vec x] = {\bf r}_{\vec w, \vec v_1, \vec v_2}$ <br><br>
#
# <b> ANSWER </b>
#
# For example: creation of a rectangle for any number of dimensions is<br><br>
# ${\bf a}[\vec x] = {\bf r}_{\vec w; \vec v_1, \vec v_2} [\vec x]$<br>
#
# where ${\bf r}_{\vec w; \vec v_1, \vec v_2} [\vec x]$ Rectangle- returns an image with a solid rectangle located at $\vec v_1$ and size $\vec v_2$<br><br>
#
# Frame size = (200, 200)
#
# Position of rectangle:  (10, 100)
#
#
# But given the starting location of (10,100), the rectangle in the horizontal direction goes beyone the frame 100 + 150 = 250 where the frame size is 200
#
# Therefore, without wrapping the rectangle is (50, 100) = 5,000 pixels
#
# And with wrapping  the rectangle is (50, 150) = 7,500 pixels
#
# <br><br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# 2. What is the value of $t$ in, $t = \sum_{\vec x} {\bf o}_{\vec w, \vec v, r}$ where $\vec w=(200,200)$, $\vec v =(100,100)$ and $r=50$? <br><br>
#
# <b> ANSWER </b>
#
# ${\bf o}_{\vec w; \vec v, r}[\vec x]$ Circle - returns an image with a solid circle of radius $r$ located at position $\vec v$<br><br>
#
# The circle is at position (100, 100) with a radius of 50
#
# This is totally contained within the frame, so the number of pixels is really a very complicated calculation since the circle cuts pixels in fractions
#
# So what does that mean???  Has no meaning and needs to be defined
#
# Most of you perform the following calculation based on the area of the circle
#
# r = 50 so pi * r^2 = 7,850<br><br>
#
# <br><br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <br><br>
#
#
# $\begin{Bmatrix} {\bf r}[\vec x] \\ {\bf g}[\vec x] \\ {\bf b}[\vec x] \end{Bmatrix} = \mathcal{L}_{RGB} {\bf a}[\vec x]$
# <br>
#
# <br><br>
#
#
# ${\bf r}[\vec x] = \begin{Bmatrix} 1 \\ \varnothing \\ \varnothing \end{Bmatrix} {\bf a}[\vec x]$
#
# ${\bf g}[\vec x] = \begin{Bmatrix}  \varnothing \\ 1 \\ \varnothing \end{Bmatrix} {\bf a}[\vec x]$
#
# <br><br>

# %% [markdown]
# 3.  Write the operator notation for the absolute value of the difference between the values in the red and green channels of an RGB image ${\bf a}[\vec x]$.
#
# <b> ANSWER </b>
#
# ${\bf b}[\vec x] = \left | \begin{Bmatrix} 1 \varnothing  \varnothing \end{Bmatrix} {\bf a}[\vec x] -  \begin{Bmatrix}  \varnothing  1  \varnothing \end{Bmatrix} {\bf a}[\vec x] \right|$
#
# or
#
# ${\bf b}[\vec x] = \lvert\begin{Bmatrix} 1 \\ \varnothing \\ \varnothing \end{Bmatrix} {\bf a}[\vec x] - \begin{Bmatrix} \varnothing \\ 1 \\ \varnothing \end{Bmatrix} {\bf a}[\vec x]\rvert$
# <br>
#
# using ${\bf r}[\vec x]$ or ${\bf g}[\vec x]$ is incorrect without defining what they are
