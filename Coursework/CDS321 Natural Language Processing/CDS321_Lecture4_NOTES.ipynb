# %% [markdown]
# ## Week 4 Notes

# %%
#import packages

import re
import regex

import pandas as pd
import numpy as np

import nltk
nltk.download('punkt')
nltk.download('stopwords')
#nltk.download('wordnet')
#nltk.download('omw-1.4')

from nltk.corpus import *
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#all to lower

inpt_str = "The 5 biggest countries by population in 2019 so far are China, India, United States, Indonesia, and Brazil."
inpt_str = inpt_str.lower()
print(inpt_str)
# Out:
# the 5 biggest countries by population in 2019 so far are china, india, united states, indonesia, and brazil.

# %%
#remove digits

inpt_str = "Box a contains 3.0 red and 55 white balls, while Box B contains 4 red and 2 blue balls. How many red balls are in Box B?"
inpt_str = re.sub(r'(\d+|\.)', '', inpt_str)
print(inpt_str)
# Out:
# Box a contains  red and  white balls, while Box B contains  red and  blue balls How many red balls are in Box B?

# %%
import string

# %%
inpt_str = "This &is [an] example? {of} string. with.? punctuation.!?"
result = inpt_str.translate(str.maketrans('', '', string.punctuation))
print(result)
# Out:
# This is an example of string with punctuation

# %%
inpt_str = "This &is [an] example? {of} string. with.? punctuation.!?"
pattern = r"\.+"
result = re.sub(pattern, '', inpt_str)
print(result)
# Out:
# This &is [an] example? {of} string with? punctuation!?

# %%
intab = "aeiou"
outtab = "12345"
trantab = str.maketrans(intab, outtab)
str = "this is string example....wow!!!"
print (str.translate(trantab))
# Out:
# th3s 3s str3ng 2x1mpl2....w4w!!!

# %%
inpt_str = "\t this is an example \n"
inpt_str = inpt_str.strip()
print(inpt_str)
# Out:
# this is an example

# %%
inpt_str = "\t this is an example \n"
pattern = r"\s+"
result = re.sub(pattern, ' ', inpt_str)
print(result)
# Out:
#  this is an example

# %%
#remove stop words

from nltk.corpus import stopwords

# %%
inpt_str = "This is an example of stop word removal. Nltk provides a list of stop words."
stop_words = set(stopwords.words('english'))
words = inpt_str.split()
filtered_words = [word for word in words if word.lower() not in stop_words]
result = ' '.join(filtered_words)
print(result)
# Out:
# example stop word removal. Nltk provides list stop words.

# %%
#use sklearn to remove stopwords

import spacy
import sklearn

from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS as sklearn_stop_words
from spacy.lang.en.stop_words import STOP_WORDS as spacy_stop_words
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-98fcb56b3b4b> in <cell line: 0>()
#       4 import sklearn
#       5
# ----> 6 from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS as sklearn_stop_words
#       7 from spacy.lang.en.stop_words import STOP_WORDS as spacy_stop_words
#
# ModuleNotFoundError: No module named 'sklearn.feature_extraction.stop_words'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ##Quiz work

# %%
url = 'http://www.gutenberg.org/files/2000/2000-0.txt'

# %%
from __future__ import division ## in your textbook this is specified for python2 users only, but actually it is working with python3 as well
import nltk, re, pprint
nltk.download('punkt_tab')
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from urllib import request
response = request.urlopen(url)
raw = response.read().decode('utf8')
type(raw)  ## you need to run each of these separately
# Out:
# str

# %%
tokens = word_tokenize(raw) ## make sure you run each of these separately

len(tokens)
# Out:
# 447919

# %%
print(tokens[:100])
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'eBook', 'of', 'Don', 'Quijote', ',', 'by', 'Miguel', 'de', 'Cervantes', 'Saavedra', 'This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', '.', 'You', 'may', 'copy', 'it', ',', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at', 'www.gutenberg.org', '.', 'If', 'you', 'are', 'not', 'located', 'in', 'the', 'United', 'States', ',', 'you', 'will', 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using', 'this', 'eBook', '.']

# %%
text = nltk.Text(tokens)
tkn_set = set(tokens)
print(len(tkn_set))
# Out:
# 25970

# %%
txt = raw.split(' ')

# %%
print(len(txt))
# Out:
# 357563

# %%
print(txt)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
